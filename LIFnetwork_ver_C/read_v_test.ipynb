# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
with open('./v_test.txt', 'r') as fid:
    vs = [float(v) for v in fid.readline().split(',')[:-1]]

# %%
t = np.arange(0, 1000.005, 0.01)

# %%
plt.figure(dpi=200, figsize=(6, 6))
plt.plot(t, vs, 'k-', lw=0.5)
# plt.xlim([0, 1])
plt.show()
